# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/CV2/Simple-CSSC
# Out:
# /content/drive/MyDrive/CV2/Simple-CSSC

# %%
# !pip install yacs

# %%
# !python main.py --cfg configs/res50_celabelsmooth_triplet.yaml --dataset prcc --root /content/drive/MyDrive/data/
# Out:
# => merge config from configs/res50_celabelsmooth_triplet.yaml
# ...
# Config:AUG:
#   RC_PROB: 0.5
#   RE_PROB: 0.5
# DATA:
#   CUHK03_CLASSIC_SPLIT: False
#   CUHK03_LABELED: False
#   DATASET: prcc
#   HEIGHT: 256
#   NUM_INSTANCES: 4
#   NUM_WORKERS: 4
#   ROOT: /content/drive/MyDrive/data/
#   SPLIT_ID: 0
#   TEST_BATCH: 128
#   TRAIN_BATCH: 128
#   WIDTH: 128
# EVAL_MODE: False
# GPU: 0
# LOSS:
#   CLA_LOSS: crossentropylabelsmooth
#   CLA_M: 0.0
#   CLA_S: 16.0
#   PAIR_LOSS: triplet
#   PAIR_M: 0.3
#   PAIR_S: 16.0
# MODEL:
#   FEATURE_DIM: 2048
#   NAME: resnet50
#   RES4_STRIDE: 1
#   RESUME:
# OUTPUT: /data/logs/prcc/res50-celabelsmooth-triplet
# SEED: 0
# TAG: res50-celabelsmooth-triplet
# TEST:
#   DISTANCE: cosine
#   EVAL_STEP: 5
#   START_EVAL: 0
# TRAIN:
#   LR_SCHEDULER:
#     DECAY_RATE: 0.1
#     STEPSIZE: [20, 40]
#   MAX_EPOCH: 100
#   OPTIMIZER:
#     LR: 0.00035
#     NAME: adam
#     WEIGHT_DECAY: 0.0005
#   START_EPOCH: 0
# ...
# Currently using GPU 0
# => PRCC loaded
# ...
