# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
# !rm -rf data/

# %%
# !pip install timm
# # !pip install -q kaggle
# # !mkdir ~/.kaggle
# # !chmod 600 ~/.kaggle/kaggle.json

# %%
# %cd /content/drive/Othercomputers/"MacBook Pro'm"/CSSC-CCReID-main/
# Out:
# /content/drive/Othercomputers/MacBook Pro'm/CSSC-CCReID-main

# %%
# !unzip /content/drive/Othercomputers/"MacBook Pro'm"/CSSC-CCReID-main/prcc.zip -d /content/drive/Othercomputers/"MacBook Pro'm"/CSSC-CCReID-main/data

# %%
# !python main.py --gpu_devices 0 --dataset prcc --dataset_root /content/drive/Othercomputers/"MacBook Pro'm"/CSSC-CCReID-main/data/ --dataset_filename prcc --save_dir /content/drive/MyDrive/logs/ImagenetV1 --save_checkpoint
# Out:
# ------------------------ Args -------------------------
# dataset: prcc
# dataset_root: /content/drive/Othercomputers/MacBook Pro'm/CSSC-CCReID-main/data/
# dataset_filename: prcc
# height: 384
# width: 192
# horizontal_flip_pro: 0.5
# pad_size: 10
# random_erasing_pro: 0.5
# split_id: 0
# train_batch: 32
# test_batch: 128
# num_workers: 8
# num_instances: 8
# start_epoch: 0
# max_epoch: 120
# margin: 0.3
# lr: 0.0003
# warm_up_factor: 0.1
# warm_up_method: linear
# warm_up_epochs: 10
# step_milestones: [30, 60]
# gamma: 0.1
# weight_decay: 0.0005
# weight_decay_bias: 0.0005
# resume:
# use_cpu: False
# gpu_devices: 0
# seed: 666
# evaluate: False
# print_train_info_epoch_freq: 5
# start_eval_epoch: 0
# eval_epoch: 5
# reranking: False
# save_dir: /content/drive/MyDrive/logs/ImagenetV1
# save_checkpoint: True
# tri_start_epoch: 35
# --------------------- Args End ------------------------
# Currently using GPU 0
# Initializing dataset prcc
# => PRCC loaded
# Dataset statistics:
# ...

# %%
# %pwd
# Out:
# "/content/drive/Othercomputers/MacBook Pro'm/CSSC-CCReID-main"

# %%
# %ls /content/drive/Othercomputers/"MacBook Pro'm"/CSSC-CCReID-main/data/prcc/rgb/test/A/001
# Out:
# cropped_rgb001.jpg  cropped_rgb022.jpg  cropped_rgb043.jpg  cropped_rgb064.jpg
# cropped_rgb004.jpg  cropped_rgb025.jpg  cropped_rgb046.jpg  cropped_rgb067.jpg
# cropped_rgb007.jpg  cropped_rgb028.jpg  cropped_rgb049.jpg  cropped_rgb070.jpg
# cropped_rgb010.jpg  cropped_rgb031.jpg  cropped_rgb052.jpg  cropped_rgb073.jpg
# cropped_rgb013.jpg  cropped_rgb034.jpg  cropped_rgb055.jpg  cropped_rgb076.jpg
# cropped_rgb016.jpg  cropped_rgb037.jpg  cropped_rgb058.jpg  cropped_rgb106.jpg
# cropped_rgb019.jpg  cropped_rgb040.jpg  cropped_rgb061.jpg
